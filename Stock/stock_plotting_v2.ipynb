# %%
# %matplotlib inline
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np
import datetime as dt
import pprint as pprint


stock_data = './Stock_final.csv'
data = pd.read_csv(stock_data)
df = data.drop(['Unnamed: 0'], axis = 1)
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d')
df = df.set_index("Date")
df
# Out:
#        SPX Open Price  SPX Volume  NYT VS (Day_Lag=-1)  WSJ VS (Day_Lag=-1)  \
# Date
# 06/06       2753.2500  3651640000               0.0069               0.2048
# 06/08       2765.8401  3123210000               0.1468               0.2277
# 06/13       2787.9399  3779230000              -0.0566               0.1921
# 06/14       2783.2100  3526890000              -0.1581               0.2882
# 06/20       2769.7300  3327600000              -0.1426               0.0725
# 06/21       2769.2800  3300060000               0.0365               0.0204
# 06/22       2760.7900  5450550000               0.0252               0.2048
# 06/27       2728.4500  3776090000              -0.0307               0.1944
# 06/28       2698.6899  3428140000               0.3676               0.3503
# 07/05       2724.1899  2953420000              -0.0656              -0.2963
# 07/06       2737.6799  2554780000               0.3665               0.1897
# 07/09       2775.6201  3050040000               0.1250               0.2238
# 07/10       2788.5601  3063850000               0.1178               0.0417
# 07/12       2783.1399  2821690000              -0.0384               0.1004
# 07/16       2797.3601  2812230000              -0.1275               0.0248
# 07/17       2789.3401  3050730000              -0.0463               0.0435
# 07/19       2809.3701  3266700000              -0.2087               0.3283
# 07/24       2820.6799  3417530000               0.0290               0.1634
# 07/26       2835.4900  3653330000               0.8264               0.1539
# 07/27       2842.3501  3415710000              -0.1628               0.2923
# 08/01       2821.1699  3496990000               0.0599               0.0930
# 08/02       2800.4800  3467380000               0.1885               0.3072
# 08/06       2840.2900  2874540000               0.2914               0.0153
# 08/07       2855.9199  3162770000               0.3502               0.2120
# 08/09       2857.1899  3047050000               0.0691               0.0948
# 08/10       2838.8999  3256040000               0.2960               0.0231
# 08/13       2835.4600  3158450000              -0.0895               0.0000
# 08/14       2827.8799  2976970000              -0.1147               0.0225
# 08/17       2838.3201  3024100000               0.0986              -0.0968
# 08/21       2861.5100  3147140000               0.1516               0.0150
# 08/22       2860.9900  2689560000               0.1597               0.1292
# 08/23       2860.2900  2713910000               0.0963              -0.0462
# 08/24       2862.3501  2596190000               0.1187              -0.0745
# 08/27       2884.6899  2854080000              -0.4573               0.3502
# 08/28       2901.4500  2683190000               0.0252               0.0768
# 08/29       2900.6201  2791860000               0.0417               0.3222
# 08/30       2908.9399  2802180000               0.1341               0.2693
#
#        CNN VS (Day_Lag=-1)
# Date
# 06/06               0.1294
# 06/08              -0.0680
# 06/13               0.3059
# 06/14               0.1673
# 06/20               0.0981
# 06/21              -0.1629
# 06/22              -0.0906
# 06/27              -0.1808
# 06/28               0.2119
# 07/05              -0.3612
# 07/06               0.0362
# 07/09               0.0554
# 07/10               0.2061
# 07/12              -0.1442
# 07/16              -0.4019
# 07/17               0.1490
# 07/19              -0.0456
# 07/24               0.2325
# 07/26               0.0066
# 07/27               0.0595
# 08/01               0.0555
# 08/02               0.1997
# 08/06               0.4939
# 08/07              -0.3055
# 08/09              -0.0370
# 08/10               0.1998
# 08/13              -0.7269
# 08/14              -0.1017
# 08/17              -0.1712
# 08/21               0.4447
# 08/22               0.4258
# 08/23               0.0257
# 08/24               0.1709
# 08/27              -0.0216
# 08/28               0.2370
# 08/29              -0.0195
# 08/30              -0.0576

# %%
price = df["SPX Open Price"]
volume = df["SPX Volume"]
vs_all = df.iloc[:,2:6]
# plotting the graph by using object oriented plot

fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

price.plot(ax=ax, label="SPX Price",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Stock Price",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 37))
# setting a title

ax.set_title("SPX Price vs Basic Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()

# fig.savefig('stock_price.png', bbox_inches='tight')
plt.show()

# %%
fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

volume.plot(ax=ax, label="SPX Volume",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Stock Volume",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 37))
# setting a title

ax.set_title("SPX Volume vs Basic Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()
# fig.savefig('stock_volume.png', bbox_inches='tight')
plt.show()
