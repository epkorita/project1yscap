# %%
# %matplotlib inline
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np
import datetime as dt
import pprint as pprint


apple_data = './Apple_final.csv'
data = pd.read_csv(apple_data)
df = data.drop(['Unnamed: 0'], axis = 1)
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d')
df = df.set_index("Date")
df
# Out:
#        AAPL Open Price  AAPL Volume  NYT VS (Day_Lag=-1)  WSJ VS (Day_Lag=-1)  \
# Date
# 06/07           194.14     21347180               0.1547               0.0281
# 06/08           191.17     26656799               0.3953               0.3125
# 06/13           192.42     21638393              -0.5994               0.2464
# 06/14           191.55     21610074              -0.2062              -0.0081
# 06/15           190.03     61719160               0.4016               0.0433
# 06/19           185.14     33578455               0.0991               0.0197
# 06/20           186.35     20628701               0.0000               0.1094
# 06/28           184.10     17365235              -0.0752               0.3047
# 06/29           186.29     22737666               0.4776               0.4571
# 07/06           185.42     17485245               0.1264              -0.2732
# 07/13           191.08     12519792               0.0224               0.2621
# 07/19           189.69     20286752               0.1918               0.1788
# 07/20           191.78     20706042               0.0159               0.0964
# 07/27           194.99     24023972              -0.1497               0.4726
# 08/03           207.03     33447396              -0.0474               0.3091
# 08/07           209.32     25587387              -0.5574              -0.3906
# 08/08           206.05     22525487               0.1872               0.0000
# 08/10           207.36     24611202              -0.4588              -0.1794
# 08/17           213.44     35426997               0.0000              -0.2887
# 08/23           214.65     18883224               0.2581              -0.3161
# 08/30           223.25     48793824              -0.0332               0.1496
#
#        CNN VS (Day_Lag=-1)
# Date
# 06/07               0.4759
# 06/08               0.2145
# 06/13               0.1723
# 06/14               0.1048
# 06/15               0.3337
# 06/19              -0.0848
# 06/20              -0.0433
# 06/28              -0.3880
# 06/29              -0.1890
# 07/06               0.0000
# 07/13              -0.1055
# 07/19               0.0155
# 07/20               0.0000
# 07/27               0.3411
# 08/03               0.2486
# 08/07              -0.1131
# 08/08              -0.1828
# 08/10               0.2094
# 08/17              -0.4350
# 08/23              -0.0201
# 08/30               0.0129

# %%
price = df["AAPL Open Price"]
volume = df["AAPL Volume"]
vs_all = df.iloc[:,2:6]
# plotting the graph by using object oriented plot

fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

price.plot(ax=ax, label="Apple Price",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Apple Price",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 21))
# setting a title

ax.set_title("Apple Price vs Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()
# fig.savefig('apple_price.png', bbox_inches='tight')
plt.show()

# %%
fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

volume.plot(ax=ax, label="Apple Volume",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Apple Volume",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 21))
# setting a title

ax.set_title("Apple Volume vs Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()
# fig.savefig('apple_volume.png', bbox_inches='tight')

plt.show()
