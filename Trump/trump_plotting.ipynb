# %%
# %matplotlib inline
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np
import datetime as dt
import pprint as pprint


trump_data = './Trump_final.csv'
data = pd.read_csv(trump_data)
df = data.drop(['Unnamed: 0'], axis = 1)
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d')
df = df.set_index("Date")
df
# Out:
#        SPX Open Price  SPX Volume  NYT VS (Day_Lag=-1)  WSJ VS (Day_Lag=-1)  \
# Date
# 08/03       2829.6201  3030390000               0.0548               0.0326
# 08/06       2840.2900  2874540000               0.0857              -0.0794
# 08/07       2855.9199  3162770000              -0.2264               0.1500
# 08/08       2856.7900  2972200000              -0.1794              -0.1171
# 08/09       2857.1899  3047050000               0.1960              -0.1176
# 08/10       2838.8999  3256040000               0.1003              -0.1155
# 08/13       2835.4600  3158450000              -0.1759              -0.0188
# 08/14       2827.8799  2976970000              -0.1181              -0.0119
# 08/15       2827.9500  3645070000               0.1333              -0.2306
# 08/16       2831.4399  3219880000              -0.2392              -0.0744
# 08/17       2838.3201  3024100000              -0.1948              -0.1117
# 08/20       2853.9299  2748020000              -0.0010              -0.0099
# 08/21       2861.5100  3147140000               0.0017               0.1182
# 08/22       2860.9900  2689560000              -0.2107              -0.0036
# 08/23       2860.2900  2713910000              -0.1046              -0.0658
# 08/24       2862.3501  2596190000               0.1010               0.0171
# 08/27       2884.6899  2854080000               0.0963              -0.0256
# 08/28       2901.4500  2683190000               0.0483               0.0859
# 08/29       2900.6201  2791860000               0.0658               0.0912
# 08/30       2908.9399  2802180000              -0.0359               0.3793
#
#        CNN VS (Day_Lag=-1)
# Date
# 08/03               0.0843
# 08/06               0.0885
# 08/07               0.0163
# 08/08              -0.0294
# 08/09               0.0340
# 08/10               0.0835
# 08/13              -0.1313
# 08/14               0.0308
# 08/15              -0.0596
# 08/16              -0.0156
# 08/17               0.0136
# 08/20               0.0343
# 08/21               0.0587
# 08/22              -0.0140
# 08/23              -0.0867
# 08/24              -0.0774
# 08/27              -0.1214
# 08/28               0.0031
# 08/29               0.0594
# 08/30               0.0397

# %%
price = df["SPX Open Price"]
volume = df["SPX Volume"]
vs_all = df.iloc[:,2:6]

# plotting the graph by using object oriented plot
fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis
ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis
price.plot(ax=ax, label="SPX Price",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks
ax.set_ylabel("Stock Price",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Trump Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index[np.arange(0,20,4)], fontdict = {"fontsize" : 12, "fontweight": "bold"})
plt.xticks(np.arange(0, 20, 4))

# setting a title
ax.set_title("SPX Price vs Trump Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper center")

# fig.savefig('trump_price.png', bbox_inches='tight')
plt.show()

# %%
# plotting the graph by using object oriented plot
fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis
ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis
volume.plot(ax=ax, label="SPX Volume",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks
ax.set_ylabel("Stock Volume",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Trump Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index[np.arange(0,20,4)], fontdict = {"fontsize" : 12, "fontweight": "bold"})
plt.xticks(np.arange(0, 20, 4))

# setting a title
ax.set_title("SPX Volume vs Trump Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper center")

# fig.savefig('trump_volume.png', bbox_inches='tight')
plt.show()
