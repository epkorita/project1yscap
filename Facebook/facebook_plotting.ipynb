# %%
# %matplotlib inline
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np
import datetime as dt
import pprint as pprint


fb_data = './Facebook_final.csv'
data = pd.read_csv(fb_data)
df = data.drop(['Unnamed: 0'], axis = 1)
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d')
df = df.set_index("Date")
len(df)
df
# Out:
#        FB Open Price  FB Volume  NYT VS (Day_Lag=-1)  WSJ VS (Day_Lag=-1)  \
# Date
# 07/05       194.7400   19684193               0.1795              -0.4076
# 07/10       204.5000   13190067               0.0880              -0.1060
# 07/11       202.2200   12927377              -0.1459               0.2857
# 07/12       203.4300   15454706              -0.1222               0.0640
# 07/13       207.8100   11503401              -0.3898               0.5429
# 07/17       204.9000   15349892               0.0085               0.3610
# 07/18       209.8200   15334907               0.2339               0.0339
# 07/19       208.7700   11350429              -0.1575               0.0350
# 07/23       210.5800   16731969               0.2728              -0.1767
# 07/25       215.7150   64592585               0.1228               0.4916
# 07/26       174.8900  169803668               0.0466               0.1494
# 07/27       179.8700   60073749              -0.0728               0.2699
# 07/31       170.6700   40356471              -0.0681               0.0178
# 08/01       173.9300   34042109               0.6042              -0.1598
# 08/02       170.6800   32399954               0.0705              -0.1107
# 08/03       177.6900   24763434               0.1604               0.1636
# 08/07       186.5000   33398562              -0.0291               0.1124
# 08/08       184.7500   22205230              -0.0550               0.0630
# 08/09       185.8492   19732120              -0.1837               0.0116
# 08/13       180.1000   17423264              -0.1502               0.3665
# 08/14       180.7100   19101995               0.2925              -0.1262
# 08/15       179.3400   33020231              -0.0822              -0.0864
# 08/16       180.4200   31351784              -0.1898               0.0859
# 08/17       174.5000   24893176              -0.1633              -0.2020
# 08/20       174.0400   21518006              -0.3954               0.1969
# 08/21       172.8100   19578514               0.0667              -0.3887
# 08/22       172.2100   16894083              -0.0908               0.0871
# 08/23       173.0900   18053567              -0.0827              -0.1217
# 08/24       173.7000   14631556              -0.1424              -0.3685
# 08/28       178.1000   15910675              -0.0819               0.0612
# 08/29       176.2950   18678301               0.0145               0.0990
# 08/30       175.9000   24216532               0.0952               0.0669
#
#        CNN VS (Day_Lag=-1)
# Date
# 07/05               0.1666
# 07/10               0.1165
# 07/11               0.1048
# 07/12               0.0719
# 07/13              -0.0916
# 07/17               0.0692
# 07/18              -0.0778
# 07/19              -0.0968
# 07/23              -0.0024
# 07/25              -0.0349
# 07/26              -0.0091
# 07/27               0.0284
# 07/31              -0.0087
# 08/01              -0.1102
# 08/02               0.0807
# 08/03              -0.0822
# 08/07              -0.1363
# 08/08              -0.0811
# 08/09              -0.0418
# 08/13              -0.0594
# 08/14               0.0154
# 08/15              -0.1506
# 08/16              -0.0830
# 08/17              -0.0421
# 08/20              -0.0492
# 08/21              -0.1060
# 08/22               0.0117
# 08/23              -0.1441
# 08/24              -0.1146
# 08/28              -0.0103
# 08/29               0.0811
# 08/30              -0.0998

# %%
price = df["FB Open Price"]
volume = df["FB Volume"]
vs_all = df.iloc[:,2:6]
# plotting the graph by using object oriented plot

fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

price.plot(ax=ax, label="Facebook Price",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Facebook Price",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 32))
# setting a title

ax.set_title("Facebook Price vs Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()
# fig.savefig('fb_price.png', bbox_inches='tight')
plt.show()

# %%
fig =plt.figure(figsize=(16,12))    # creating figure object
ax = fig.add_subplot(212)           # adding axes on this figure

# instantiate a second axes that shares the same x-axis

ax3 = ax.twinx()

# ploting Stock price and Vader Score on the same axis

volume.plot(ax=ax, label="Facebook Volume",color="b", marker="o", markersize=10, lw=5,ls='--', alpha=1)
vs_all.plot(ax=ax3, label="Vader Score",color=["r","g","y"],markersize=10, lw=4,ls='-',alpha=1)


# designing labile and ticks

ax.set_ylabel("Facebook Volume",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xlabel("Date",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax3.set_ylabel("Vader Score",fontdict = {"fontsize" : 22, "fontweight": "bold"})
ax.set_xticklabels(df.index, fontdict = {"fontsize" : 12, "fontweight": "bold"}, rotation = 75)
ax.set_xticks(np.arange(0, 32))
# setting a title

ax.set_title("Facebook Volume vs Vader Score", fontdict = {"fontsize" : 28, "fontweight": "bold"})
ax.legend(numpoints = 2, frameon = True, markerscale = 1.5, edgecolor = 'blue', fontsize = '12', framealpha = 1, loc="upper left")
ax.grid()
# fig.savefig('fb_volume.png', bbox_inches='tight')

plt.show()
